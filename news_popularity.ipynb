# %%
# Importing library

import numpy as np         
import pandas as pd        
import seaborn as sns
from matplotlib import pyplot
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Ignoring Warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# loading Dataset

#import os
#os.chdir("C:/Users/Home/Desktop/Lab/Z- Capstone Project")
df=pd.read_csv("OnlineNewsPopularity.csv")

# %%
df.shape
# Out:
# (39644, 61)

# %%
df.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs   ...     \
# ...

# %%
df.tail()
# Out:
#                                                      url   timedelta  \
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...         8.0
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...         8.0
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...         8.0
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/         8.0
# 39643  http://mashable.com/2014/12/27/youtube-channel...         8.0
#
#         n_tokens_title   n_tokens_content   n_unique_tokens  \
# 39639             11.0              346.0          0.529052
# 39640             12.0              328.0          0.696296
# 39641             10.0              442.0          0.516355
# 39642              6.0              682.0          0.539493
# 39643             10.0              157.0          0.701987
#
#         n_non_stop_words   n_non_stop_unique_tokens   num_hrefs  \
# 39639                1.0                   0.684783         9.0
# ...

# %%
df.columns
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
# ...

# %%
# Removing space character in the feature names

df.columns=df.columns.str.replace(' ','')

# %%
df.columns
# Out:
# Index(['url', 'timedelta', 'n_tokens_title', 'n_tokens_content',
#        'n_unique_tokens', 'n_non_stop_words', 'n_non_stop_unique_tokens',
#        'num_hrefs', 'num_self_hrefs', 'num_imgs', 'num_videos',
#        'average_token_length', 'num_keywords', 'data_channel_is_lifestyle',
#        'data_channel_is_entertainment', 'data_channel_is_bus',
#        'data_channel_is_socmed', 'data_channel_is_tech',
#        'data_channel_is_world', 'kw_min_min', 'kw_max_min', 'kw_avg_min',
#        'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 'kw_max_avg',
#        'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares',
#        'self_reference_avg_sharess', 'weekday_is_monday', 'weekday_is_tuesday',
#        'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday',
#        'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00',
#        'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity',
# ...

# %%
# Checking Null Values
df.isnull().sum()
# Out:
# url                              0
# timedelta                        0
# n_tokens_title                   0
# n_tokens_content                 0
# n_unique_tokens                  0
# n_non_stop_words                 0
# n_non_stop_unique_tokens         0
# num_hrefs                        0
# num_self_hrefs                   0
# num_imgs                         0
# num_videos                       0
# average_token_length             0
# num_keywords                     0
# data_channel_is_lifestyle        0
# data_channel_is_entertainment    0
# data_channel_is_bus              0
# data_channel_is_socmed           0
# data_channel_is_tech             0
# data_channel_is_world            0
# kw_min_min                       0
# kw_max_min                       0
# kw_avg_min                       0
# kw_min_max                       0
# kw_max_max                       0
# kw_avg_max                       0
# kw_min_avg                       0
# kw_max_avg                       0
# ...

# %%
# Getting details about the numerical columns
df.describe().T
# Out:
#                                  count           mean            std      min  \
# timedelta                      39644.0     354.530471     214.163767  8.00000
# n_tokens_title                 39644.0      10.398749       2.114037  2.00000
# n_tokens_content               39644.0     546.514731     471.107508  0.00000
# n_unique_tokens                39644.0       0.548216       3.520708  0.00000
# n_non_stop_words               39644.0       0.996469       5.231231  0.00000
# n_non_stop_unique_tokens       39644.0       0.689175       3.264816  0.00000
# num_hrefs                      39644.0      10.883690      11.332017  0.00000
# num_self_hrefs                 39644.0       3.293638       3.855141  0.00000
# num_imgs                       39644.0       4.544143       8.309434  0.00000
# num_videos                     39644.0       1.249874       4.107855  0.00000
# average_token_length           39644.0       4.548239       0.844406  0.00000
# ...

# %% [markdown]
# # Explorative Data Analysis

# %% [markdown]
# # Univariate Analysis

# %%
sns.distplot(df['average_token_length'])
plt.title("Average length of the words in the content")
plt.ylabel('count')
plt.plot()
# Out:
# []

# %%
sns.distplot(df['num_hrefs'])
plt.title("Number of links in the article")
plt.ylabel('count')
plt.plot()
# Out:
# []

# %%
sns.distplot(df['num_imgs'])
plt.title('Number of images in the article')
plt.ylabel('count')
plt.plot()
# Out:
# []

# %%
sns.distplot(df['num_videos'])
plt.title("Number of videos in the article")
plt.ylabel('count')
plt.plot()
# Out:
# []

# %%
sns.distplot(df['num_keywords'])
plt.title("Average keywords in the title")
plt.ylabel('count')
plt.plot()
# Out:
# []

# %%
sns.scatterplot(data=df['kw_min_min'])
plt.title("maximum Worst keyword")
plt.xlabel('Worst keyword')
plt.ylabel('count')
plt.show()
plt.clf()

# %%
sns.scatterplot(data=df['kw_max_max'])
plt.title("Maximum Best keyword")
plt.xlabel('Best keyword')
plt.ylabel('count')
plt.show()
plt.clf()

# %%
sns.scatterplot(data=df['kw_max_avg'])
plt.title("Maximum average keyword")
plt.xlabel('Average keyword')
plt.ylabel('count')
plt.show()
plt.clf()

# %%
sns.boxplot(df['shares'])
plt.title("Total Shares")
plt.show()
plt.clf()

# %%
sns.boxplot(df['num_keywords'])
plt.title("Average keywords in the title")
plt.plot()
# Out:
# []

# %% [markdown]
# # Bi-Variate Analysis

# %%
cols = ['num_imgs', 'num_videos']
df[cols].sum().plot(kind='bar',color=('blue','green'))
plt.title("No. of Images and Videos")
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
sns.regplot(x="n_tokens_title", y="shares", data=df)
plt.title("Number of words in the title  and Shares")
# Out:
# Text(0.5, 1.0, 'Number of words in the title  and Shares')

# %%
sns.jointplot(x='n_tokens_content', y='shares', data=df);

plt.title("Number of words in the content  and Shares")
# Out:
# Text(0.5, 1.0, 'Number of words in the content  and Shares')

# %% [markdown]
# # Multivariate Analysis

# %%
cols = ['data_channel_is_lifestyle', 'data_channel_is_entertainment', 'data_channel_is_bus', 'data_channel_is_socmed',
               'data_channel_is_tech', 'data_channel_is_world']
df[cols].sum().plot(kind='bar')
plt.title('Analysis of different channels in an article')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
cols = ['weekday_is_monday', 'weekday_is_tuesday', 'weekday_is_wednesday', 'weekday_is_thursday',
               'weekday_is_friday', 'weekday_is_saturday', 'weekday_is_sunday'
               ]
df[cols].sum().plot(kind='bar',color='g')
plt.title('Number of articles published')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
cols = ['kw_min_min','kw_max_min','kw_avg_min', 'kw_min_max','kw_max_max', 'kw_avg_max','kw_min_avg','kw_max_avg','kw_avg_avg']
df[cols].sum().plot(kind='bar')
plt.title('Keywords Comparison')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
df.hist(layout=(10,6),figsize=(20,29));

# %%
# box and whisker plots 
df.plot(kind ='box', subplots = True,layout =(10,6), figsize=(19,29), sharex = False, sharey = False) 
plt.show()

# %%
# Droping  url & timedelta

df1=df.drop(["url","timedelta"], axis=1)

# %%
df1.head()
# Out:
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# 0                  0.815385        4.0             2.0       1.0         0.0
# 1                  0.791946        3.0             1.0       1.0         0.0
# 2                  0.663866        3.0             1.0       1.0         0.0
# 3                  0.665635        9.0             0.0       1.0         0.0
# 4                  0.540890       19.0            19.0      20.0         0.0
#
# ...

# %%
df1.shape
# Out:
# (39644, 59)

# %%
# Droping catogorical values from df1.
# Now df2_num  dataframe contains numerical feaures.

df2_num=df1.drop(["weekday_is_monday","weekday_is_tuesday","weekday_is_wednesday","weekday_is_thursday",
                  "weekday_is_friday","weekday_is_saturday","weekday_is_sunday","is_weekend",                  
                  "data_channel_is_lifestyle","data_channel_is_entertainment","data_channel_is_bus",
                  "data_channel_is_socmed","data_channel_is_tech","data_channel_is_world"],axis=1)

# %%
df2_num.shape
# Out:
# (39644, 45)

# %%
df2_num.describe().T
# Out:
#                                 count           mean            std      min  \
# n_tokens_title                39644.0      10.398749       2.114037  2.00000
# n_tokens_content              39644.0     546.514731     471.107508  0.00000
# n_unique_tokens               39644.0       0.548216       3.520708  0.00000
# n_non_stop_words              39644.0       0.996469       5.231231  0.00000
# n_non_stop_unique_tokens      39644.0       0.689175       3.264816  0.00000
# num_hrefs                     39644.0      10.883690      11.332017  0.00000
# num_self_hrefs                39644.0       3.293638       3.855141  0.00000
# num_imgs                      39644.0       4.544143       8.309434  0.00000
# num_videos                    39644.0       1.249874       4.107855  0.00000
# average_token_length          39644.0       4.548239       0.844406  0.00000
# num_keywords                  39644.0       7.223767       1.909130  1.00000
# ...

# %%
# df2_cat dataframe contains catagoricl features.

df2_cat=df1[["weekday_is_monday","weekday_is_tuesday","weekday_is_wednesday","weekday_is_thursday",
             "weekday_is_friday","weekday_is_saturday","weekday_is_sunday","is_weekend",            
             "data_channel_is_lifestyle","data_channel_is_entertainment","data_channel_is_bus",
                  "data_channel_is_socmed","data_channel_is_tech","data_channel_is_world"]]

# %%
df2_cat.shape
# Out:
# (39644, 14)

# %%
df2_cat.describe().T
# Out:
#                                  count      mean       std  min  25%  50%  \
# weekday_is_monday              39644.0  0.168020  0.373889  0.0  0.0  0.0
# weekday_is_tuesday             39644.0  0.186409  0.389441  0.0  0.0  0.0
# weekday_is_wednesday           39644.0  0.187544  0.390353  0.0  0.0  0.0
# weekday_is_thursday            39644.0  0.183306  0.386922  0.0  0.0  0.0
# weekday_is_friday              39644.0  0.143805  0.350896  0.0  0.0  0.0
# weekday_is_saturday            39644.0  0.061876  0.240933  0.0  0.0  0.0
# weekday_is_sunday              39644.0  0.069039  0.253524  0.0  0.0  0.0
# is_weekend                     39644.0  0.130915  0.337312  0.0  0.0  0.0
# data_channel_is_lifestyle      39644.0  0.052946  0.223929  0.0  0.0  0.0
# data_channel_is_entertainment  39644.0  0.178009  0.382525  0.0  0.0  0.0
# data_channel_is_bus            39644.0  0.157855  0.364610  0.0  0.0  0.0
# data_channel_is_socmed         39644.0  0.058597  0.234871  0.0  0.0  0.0
# ...

# %%
#Finding correlation of each features in a dataset.
cor = df2_num.corr()
cor
# Out:
#                               n_tokens_title  n_tokens_content  \
# n_tokens_title                      1.000000          0.018160
# n_tokens_content                    0.018160          1.000000
# n_unique_tokens                    -0.005318         -0.004737
# n_non_stop_words                   -0.004754          0.017512
# n_non_stop_unique_tokens           -0.005420          0.000373
# num_hrefs                          -0.053496          0.423065
# num_self_hrefs                     -0.014856          0.304682
# num_imgs                           -0.008858          0.342600
# num_videos                          0.051460          0.103699
# average_token_length               -0.071403          0.167789
# num_keywords                       -0.006077          0.072845
# kw_min_min                         -0.110672         -0.054345
# kw_max_min                         -0.005890          0.000066
# kw_avg_min                         -0.031400         -0.003545
# ...

# %%
# finding correlation graterthan 0.5 and not equalto 1.

cor[abs(cor > 0.5) & (cor != 1)]
# Out:
#                               n_tokens_title  n_tokens_content  \
# n_tokens_title                           NaN               NaN
# n_tokens_content                         NaN               NaN
# n_unique_tokens                          NaN               NaN
# n_non_stop_words                         NaN               NaN
# n_non_stop_unique_tokens                 NaN               NaN
# num_hrefs                                NaN               NaN
# num_self_hrefs                           NaN               NaN
# num_imgs                                 NaN               NaN
# num_videos                               NaN               NaN
# average_token_length                     NaN               NaN
# num_keywords                             NaN               NaN
# kw_min_min                               NaN               NaN
# kw_max_min                               NaN               NaN
# kw_avg_min                               NaN               NaN
# ...

# %%
#Droping highly correlated features and target feature

df2_num_new=df2_num.drop(["n_non_stop_unique_tokens","n_non_stop_words","kw_avg_min","shares"], axis=1)

# %%
df2_num_new.shape
# Out:
# (39644, 41)

# %%
# creating a new copy of df2_num_new

df3=df2_num_new

# %%
# Checking skewness
df3.skew()
# Out:
# n_tokens_title                    0.165320
# n_tokens_content                  2.945422
# n_unique_tokens                 198.655116
# num_hrefs                         4.013495
# num_self_hrefs                    5.172751
# num_imgs                          3.946596
# num_videos                        7.019533
# average_token_length             -4.576012
# num_keywords                     -0.147251
# kw_min_min                        2.374947
# kw_max_min                       35.328434
# kw_min_max                       10.386372
# kw_max_max                       -2.644982
# kw_avg_max                        0.624310
# kw_min_avg                        0.467976
# kw_max_avg                       16.411670
# kw_avg_avg                        5.760177
# self_reference_min_shares        26.264364
# self_reference_max_shares        13.870849
# self_reference_avg_sharess       17.914093
# LDA_00                            1.567463
# LDA_01                            2.086722
# ...

# %%
# Applying power transformation. method = BOX-COX

# %%
# Finding negative values.

negcols=df3.columns[(df3<=0).any()]
negcols
# Out:
# Index(['n_tokens_content', 'n_unique_tokens', 'num_hrefs', 'num_self_hrefs',
#        'num_imgs', 'num_videos', 'average_token_length', 'kw_min_min',
#        'kw_max_min', 'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg',
#        'kw_max_avg', 'kw_avg_avg', 'self_reference_min_shares',
#        'self_reference_max_shares', 'self_reference_avg_sharess', 'LDA_00',
#        'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity',
#        'global_sentiment_polarity', 'global_rate_positive_words',
#        'global_rate_negative_words', 'rate_positive_words',
#        'rate_negative_words', 'avg_positive_polarity', 'min_positive_polarity',
#        'max_positive_polarity', 'avg_negative_polarity',
#        'min_negative_polarity', 'max_negative_polarity', 'title_subjectivity',
#        'title_sentiment_polarity', 'abs_title_subjectivity',
#        'abs_title_sentiment_polarity'],
#       dtype='object')

# %%
#converting negative values to positive values for applying Box-Cox method and creating new feature.

for i in negcols:
    m=df3[i].min()
    name=i +'_new'
    print(name)
    df3[name]=((df3[i]+1)-m)
# Out:
# n_tokens_content_new
# n_unique_tokens_new
# num_hrefs_new
# num_self_hrefs_new
# num_imgs_new
# num_videos_new
# average_token_length_new
# kw_min_min_new
# kw_max_min_new
# kw_min_max_new
# kw_max_max_new
# kw_avg_max_new
# kw_min_avg_new
# kw_max_avg_new
# kw_avg_avg_new
# self_reference_min_shares_new
# self_reference_max_shares_new
# self_reference_avg_sharess_new
# LDA_00_new
# LDA_01_new
# LDA_02_new
# LDA_03_new
# LDA_04_new
# global_subjectivity_new
# global_sentiment_polarity_new
# global_rate_positive_words_new
# global_rate_negative_words_new
# rate_positive_words_new
# rate_negative_words_new
# avg_positive_polarity_new
# min_positive_polarity_new
# max_positive_polarity_new
# avg_negative_polarity_new
# min_negative_polarity_new
# max_negative_polarity_new
# title_subjectivity_new
# title_sentiment_polarity_new
# abs_title_subjectivity_new
# abs_title_sentiment_polarity_new

# %%
# Droping old negative column

for i in negcols:
    df3.drop(i,axis=1,inplace=True)

# %%
# Checking negative columns

negcols=df3.columns[(df3<=0).any()]
negcols
# Out:
# Index([], dtype='object')

# %%
# Applying Box-cox Method

from sklearn import preprocessing
pt=preprocessing.PowerTransformer(method='box-cox',standardize=False)
BC_data=pt.fit_transform(df3)

# %%
bc_data=(pd.DataFrame(BC_data,columns=df3.columns))

# %%
# Applying Box-Cox method, Once again checking for skewness.

bc_data.skew()
# Out:
# n_tokens_title                     -0.001477
# num_keywords                       -0.088987
# n_tokens_content_new                0.148290
# n_unique_tokens_new                -0.495261
# num_hrefs_new                       0.009335
# num_self_hrefs_new                 -0.000939
# num_imgs_new                        0.180180
# num_videos_new                      0.671962
# average_token_length_new            0.361336
# kw_min_min_new                      0.547601
# kw_max_min_new                      0.468510
# kw_min_max_new                     -0.064169
# kw_max_max_new                     -1.762539
# kw_avg_max_new                     -0.054480
# kw_min_avg_new                     -0.223061
# kw_max_avg_new                      0.766526
# kw_avg_avg_new                      0.610995
# self_reference_min_shares_new      -0.029696
# self_reference_max_shares_new      -0.100769
# self_reference_avg_sharess_new     -0.090107
# LDA_00_new                          0.801063
# ...

# %%
bc_data.plot(kind ='box', subplots = True,layout =(10,6), figsize=(19,29), sharex = False, sharey = False) 
plt.show()

# %%
# Checking outlier once again after applying Box-Cox method.

# %%
sns.boxplot(bc_data['n_tokens_content_new'])

# %%
bc_data['kw_max_min_new'].describe().T
# Out:
# count    39644.000000
# mean        13.350379
# std          3.982982
# min          0.000000
# 25%         11.828717
# 50%         13.193647
# 75%         14.753095
# max         55.991639
# Name: kw_max_min_new, dtype: float64

# %%
# Outliers treatment.

# %%
#Treating outlier :  

for col in bc_data.columns:
    percentiles = bc_data[col].quantile([0.01,0.99]).values
    bc_data[col][bc_data[col] <= percentiles[0]] = percentiles[0]
    bc_data[col][bc_data[col] >= percentiles[1]] = percentiles[1]

# %%
bc_data.plot(kind ='box', subplots = True,layout =(10,6), figsize=(19,29), sharex = False, sharey = False) 
plt.show()

# %%
# Combining numeric features and catogorical features.

df3_con=pd.concat([bc_data,df2_cat],axis=1)

# %%
df3_con.shape
# Out:
# (39644, 55)

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
X=df3_con

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
popular_label = pd.Series(label_encoder.fit_transform(df1['shares']>=1400))

# %%
y=popular_label

# %%
model = ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [0.02200728 0.02082585 0.02129447 0.02246282 0.02342777 0.01966822
#  0.02053305 0.01657964 0.02177667 0.01570098 0.02190914 0.0180294
#  0.01336794 0.02301744 0.02207696 0.02957927 0.03294359 0.02382018
#  0.02478704 0.02369362 0.02450102 0.02204669 0.0278301  0.0219821
#  0.02383063 0.02163513 0.02193272 0.02192577 0.02105778 0.02013201
#  0.02016363 0.02054635 0.02103435 0.01892493 0.01977137 0.01982031
#  0.019603   0.01776393 0.01706522 0.017625   0.01768095 0.01048084
#  0.01039509 0.01066376 0.01043529 0.00928016 0.00395493 0.00347802
#  0.0145858  0.0041702  0.01506885 0.00554644 0.00866679 0.00748577
#  0.01141373]

# %%
feat_importances=pd.Series(model.feature_importances_,index=X.columns)

# %%
plt.figure(figsize=(19,10))
feat_importances.nlargest(35).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)
from sklearn.linear_model import LogisticRegression
modelscores=[]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

logr = LogisticRegression()

logr.fit(X_train,y_train)
ypred=logr.predict(X_test)

print("Tain score: " ,logr.score(X_train, y_train)) #trainscore

lr_score=metrics.accuracy_score(y_test, ypred)
print("Test Score: ", lr_score) #testscore



lr_score=metrics.classification_report(y_test,ypred)
print(lr_score1)
modelscores.append(['log',lr_score])
# Out:
# Tain score:  0.5349549549549549
# Test Score:  0.5304355137043888
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      5585
#            1       0.53      1.00      0.69      6309
#
#    micro avg       0.53      0.53      0.53     11894
#    macro avg       0.27      0.50      0.35     11894
# weighted avg       0.28      0.53      0.37     11894

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

knn.fit(X_train,y_train)
ypred1=knn.predict(X_test)

print("Tain score: " ,knn.score(X_train, y_train)) #trainscore

knn_score=metrics.accuracy_score(y_test, ypred1)
print("Test Score: ", knn_score) #testscore



lr_score1=metrics.classification_report(y_test,ypred1)
print(lr_score1)
modelscores.append(['knn',lr_score1])
# Out:
# Tain score:  0.707963963963964
# Test Score:  0.5283336135866824
#               precision    recall  f1-score   support
#
#            0       0.50      0.48      0.49      5585
#            1       0.55      0.57      0.56      6309
#
#    micro avg       0.53      0.53      0.53     11894
#    macro avg       0.53      0.53      0.53     11894
# weighted avg       0.53      0.53      0.53     11894

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier()
dtc.fit(X_train,y_train)

ypred2=dtc.predict(X_test)

print("Tain score: " ,dtc.score(X_train, y_train)) #trainscore

dtc_score=metrics.accuracy_score(y_test, ypred2)
print("Test Score: ", dtc_score) #testscore


lr_score2=metrics.classification_report(y_test,ypred2)
print(lr_score1)
modelscores.append(['DecisionTree',lr_score2])
# Out:
# Tain score:  1.0
# Test Score:  0.5850008407600471
#               precision    recall  f1-score   support
#
#            0       0.50      0.48      0.49      5585
#            1       0.55      0.57      0.56      6309
#
#    micro avg       0.53      0.53      0.53     11894
#    macro avg       0.53      0.53      0.53     11894
# weighted avg       0.53      0.53      0.53     11894

# %%
from sklearn.naive_bayes import GaussianNB

gb=GaussianNB()
gb.fit(X_train,y_train)

ypred3=gb.predict(X_test)

print("Tain score: " ,gb.score(X_train, y_train)) #trainscore

gb_score=metrics.accuracy_score(y_test, ypred3)
print("Test Score: ", gb_score) #testscore



lr_score3=metrics.classification_report(y_test,ypred3)
print(lr_score1)
modelscore.append(['GB',lr_score])

# %% [markdown]
# # PCA

# %%
X=df3_con

# %%
# Encode the label by threshold 1400
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
popular_label = pd.Series(label_encoder.fit_transform(df1['shares']>=1400))

# %%
y=popular_label

# %%
y.value_counts()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)

# %%
from sklearn.decomposition import PCA

# with all features as input
pca = PCA()
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
# Fitting Logistic Regression To the training set  and predict with test data


from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# making confusion matrix between 
#  test set of Y and predicted value. 

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

cm = confusion_matrix(y_test, y_pred)
print(cm)

print('Accuracy : ' + str(accuracy_score(y_test, y_pred)) )

# %%
pca.explained_variance_ratio_

# %%
#SCREE PLOT
#Explained variance
plt.plot(pca.explained_variance_ratio_)
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
## PCA using 1 features

pca = PCA(n_components=1)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
modelscores=[]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

logr = LogisticRegression()

logr.fit(X_train,y_train)
ypred=logr.predict(X_test)

print("Tain score: " ,logr.score(X_train, y_train)) #trainscore

lr_score=metrics.accuracy_score(y_test, ypred)
print("Test Score: ", lr_score) #testscore



lr_score1=metrics.classification_report(y_test,ypred)
print(lr_score1)

# %%
modelscore.append(['log',lr_score])

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

knn.fit(X_train,y_train)
ypred1=knn.predict(X_test)

print("Tain score: " ,knn.score(X_train, y_train)) #trainscore

knn_score=metrics.accuracy_score(y_test, ypred1)
print("Test Score: ", knn_score) #testscore



lr_score1=metrics.classification_report(y_test,ypred1)
print(lr_score1)

# %%
modelscore.append(['Knn',knn_score])

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier()
dtc.fit(X_train,y_train)

ypred2=dtc.predict(X_test)

print("Tain score: " ,dtc.score(X_train, y_train)) #trainscore

dtc_score=metrics.accuracy_score(y_test, ypred2)
print("Test Score: ", dtc_score) #testscore


lr_score1=metrics.classification_report(y_test,ypred2)
print(lr_score1)

# %%
modelscore.append(['DT',dtc_score])

# %%
from sklearn.naive_bayes import GaussianNB

gb=GaussianNB()
gb.fit(X_train,y_train)

ypred3=gb.predict(X_test)

print("Tain score: " ,gb.score(X_train, y_train)) #trainscore

gb_score=metrics.accuracy_score(y_test, ypred3)
print("Test Score: ", gb_score) #testscore



lr_score1=metrics.classification_report(y_test,ypred3)
print(lr_score1)

# %%
modelscore.append(['GB',gb_score])

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier()
rf.fit(X_train,y_train)

ypred4=rf.predict(X_test)

print("Tain score: " ,rf.score(X_train, y_train)) #trainscore

rf_score=metrics.accuracy_score(y_test, ypred4)
print("Test Score: ", rf_score) #testscore


lr_score1=metrics.classification_report(y_test,ypred4)
print(lr_score1)

# %%
modelscore.append(['rf',rf_score])

# %%
from xgboost import XGBClassifier

# %%
Xgb = XGBClassifier()
Xgb.fit(X_train,y_train)

ypred4=Xgb.predict(X_test)

print("Tain score: " ,Xgb.score(X_train, y_train)) #trainscore

Xgb_score=metrics.accuracy_score(y_test, ypred4)
print("Test Score: ", Xgb_score) #testscore


lr_score1=metrics.classification_report(y_test,ypred4)
print(lr_score1)

# %%
modelscore.append(['Xgboost',Xgb_score])

# %%
import lightgbm as lgb
from sklearn.metrics import roc_auc_score

train_data=lgb.Dataset(X_train,label=y_train)

#setting parameters for lightgbm
param = {'num_leaves':150, 'objective':'binary','max_depth':7,'learning_rate':.05,'max_bin':200}
param['metric'] = ['auc', 'binary_logloss']

#training our model using light gbm
num_round=50
lgbm=lgb.train(param,train_data,num_round)

#now predicting our model on test set 
ypred2=lgbm.predict(X_test)

auc_lgbm = roc_auc_score(y_test,ypred2)
auc_lgbm

# %%
modelscore.append(['light_gbm',auc_lgbm])

# %%
from sklearn.ensemble import AdaBoostClassifier
adboost=AdaBoostClassifier(base_estimator=rf,n_estimators=100,random_state=0)
adboost.fit(X_train,y_train)
pred_adboost=adboost.predict(X_test)
cm_adboost=metrics.classification_report(y_test,pred_adboost)
print(cm_adboost)

# %%
cm_adboost1=metrics.accuracy_score(y_test,pred_adboost)
print(cm_adboost1)

# %%
modelscore.append(['adboost',cm_adboost1])

# %%
scores = pd.DataFrame(modelscore, columns =['Name', 'Score']) 
scores.sort_values(by=['Score'], inplace=True, ascending=False)
scores.set_index('Name', inplace=True)
scores

# %% [markdown]
# # RFE Features:40

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE
logreg = LogisticRegression()
rfe = RFE(logreg, 40)             # running RFE with 13 variables as output
rfe = rfe.fit(X,y)
print(rfe.support_)           # Printing the boolean results
print(rfe.ranking_)

# %%
cols = list(X.columns)
model = LogisticRegression()
#Initializing RFE model
rfe = RFE(model, 40)             
#Transforming data using RFE
X_rfe = rfe.fit_transform(X,y)  
#Fitting the data to model
model.fit(X_rfe,y)              
temp = pd.Series(rfe.support_,index = cols)
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)

# %%
df7=df3_con[['n_tokens_title', 'num_keywords', 'n_tokens_content_new',
       'n_unique_tokens_new', 'num_hrefs_new', 'num_self_hrefs_new',
       'num_imgs_new', 'num_videos_new', 'average_token_length_new',
       'kw_min_min_new', 'kw_max_min_new', 'kw_min_max_new', 'kw_max_max_new',
       'kw_avg_max_new', 'kw_min_avg_new', 'kw_max_avg_new', 'kw_avg_avg_new',
       'self_reference_min_shares_new', 'self_reference_max_shares_new',
       'self_reference_avg_sharess_new', 'LDA_04_new',
       'global_subjectivity_new', 'global_sentiment_polarity_new',
       'rate_positive_words_new', 'avg_positive_polarity_new',
       'max_positive_polarity_new', 'avg_negative_polarity_new',
       'min_negative_polarity_new', 'max_negative_polarity_new',
       'title_subjectivity_new', 'title_sentiment_polarity_new',
       'abs_title_subjectivity_new', 'weekday_is_saturday',
       'weekday_is_sunday', 'is_weekend', 'data_channel_is_lifestyle',
       'data_channel_is_entertainment', 'data_channel_is_socmed',
       'data_channel_is_tech', 'data_channel_is_world']]

# %%
df7.shape

# %%
X=df7

# %%
y=popular_label

# %%
modelscore_rf=[]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

logr_rf = LogisticRegression()

logr_rf.fit(X_train,y_train)
ypred=logr_rf.predict(X_test)

print("Tain score: " ,logr_rf.score(X_train, y_train)) #trainscore

lrrfe_score=metrics.accuracy_score(y_test, ypred)
print("Test Score: ", lrrfe_score) #testscore



lr_score1=metrics.classification_report(y_test,ypred)
print(lr_score1)

# %%
modelscore_rf.append(['log_rfe',lrrfe_score])

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_rf=KNeighborsClassifier()

knn_rf.fit(X_train,y_train)
ypred1=knn_rf.predict(X_test)

print("Tain score: " ,knn_rf.score(X_train, y_train)) #trainscore

knnrfe_score=metrics.accuracy_score(y_test, ypred1)
print("Test Score: ", knnrfe_score) #testscore



lr_score1=metrics.classification_report(y_test,ypred1)
print(lr_score1)

# %%
modelscore_rf.append(['knn_rfe',knnrfe_score])

# %%
from sklearn.tree import DecisionTreeClassifier

dtc_rf=DecisionTreeClassifier()
dtc_rf.fit(X_train,y_train)

ypred2=dtc_rf.predict(X_test)

print("Tain score: " ,dtc_rf.score(X_train, y_train)) #trainscore

dtcrfe_score=metrics.accuracy_score(y_test, ypred2)
print("Test Score: ", dtcrfe_score) #testscore


lr_score1=metrics.classification_report(y_test,ypred2)
print(lr_score1)

# %%
modelscore_rf.append(['dtc_rfe',dtcrfe_score])

# %%
from sklearn.naive_bayes import GaussianNB

gb_rf=GaussianNB()
gb_rf.fit(X_train,y_train)

ypred3=gb_rf.predict(X_test)

print("Tain score: " ,gb_rf.score(X_train, y_train)) #trainscore

gbrfe_score=metrics.accuracy_score(y_test, ypred3)
print("Test Score: ", gbrfe_score) #testscore


lr_score1=metrics.classification_report(y_test,ypred3)
print(lr_score1)

# %%
modelscore_rf.append(['gb_rfe',gbrfe_score])

# %%
from sklearn.ensemble import RandomForestClassifier

rf_rfe=RandomForestClassifier()
rf_rfe.fit(X_train,y_train)

ypred4=rf_rfe.predict(X_test)

print("Tain score: " ,rf_rfe.score(X_train, y_train)) #trainscore

rf_rfe_score=metrics.accuracy_score(y_test, ypred4)
print("Test Score: ", rf_rfe_score) #testscore


lr_score1=metrics.classification_report(y_test,ypred4)
print(lr_score1)

# %%
modelscore_rf.append(['rf_rfe',rf_rfe_score])

# %% [raw]
# # Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier
adboost=AdaBoostClassifier(base_estimator=rf_rfe,n_estimators=100,random_state=0)
adboost.fit(X_train,y_train)
pred_adboost=adboost.predict(X_test)
cm_adboost=metrics.classification_report(y_test,pred_adboost)
print(cm_adboost)
cm_adboost1=metrics.accuracy_score(y_test,pred_adboost)
print("Accuracy:",cm_adboost1)

# %%
modelscore_rf.append(['adboost',cm_adboost1])

# %%
from xgboost import XGBClassifier
Xgb = XGBClassifier()
Xgb.fit(X_train,y_train)

ypred4=Xgb.predict(X_test)

print("Tain score: " ,Xgb.score(X_train, y_train)) #trainscore

Xgb_score=metrics.accuracy_score(y_test, ypred4)
print("Test Score: ", Xgb_score) #testscore

# %%
modelscore_rf.append(['XGboost',Xgb_score])

# %%
import lightgbm as lgb
from sklearn.metrics import roc_auc_score

train_data=lgb.Dataset(X_train,label=y_train)

#setting parameters for lightgbm
param = {'num_leaves':150, 'objective':'binary','max_depth':7,'learning_rate':.05,'max_bin':200}
param['metric'] = ['auc', 'binary_logloss']

#training our model using light gbm
num_round=50
lgbm=lgb.train(param,train_data,num_round)

#now predicting our model on test set 
ypred2=lgbm.predict(X_test)

auc_lgbm = roc_auc_score(y_test,ypred2)
auc_lgbm

# %%
modelscore_rf.append(['light gbm',auc_lgbm])

# %%
scores = pd.DataFrame(modelscore_rf, columns =['Name', 'Score']) 
scores.sort_values(by=['Score'], inplace=True,ascending=False)
scores.set_index('Name', inplace=True)
scores

# %% [markdown]
# # RFE Features:50

# %%
cols = list(X.columns)
model = LogisticRegression()
#Initializing RFE model
rfe = RFE(model, 50)             
#Transforming data using RFE
X_rfe = rfe.fit_transform(X,y)  
#Fitting the data to model
model.fit(X_rfe,y)              
temp = pd.Series(rfe.support_,index = cols)
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)

# %%
df8=df3_con[['n_tokens_title', 'num_keywords', 'n_tokens_content_new',
       'n_unique_tokens_new', 'num_hrefs_new', 'num_self_hrefs_new',
       'num_imgs_new', 'num_videos_new', 'average_token_length_new',
       'kw_min_min_new', 'kw_max_min_new', 'kw_min_max_new', 'kw_max_max_new',
       'kw_avg_max_new', 'kw_min_avg_new', 'kw_max_avg_new', 'kw_avg_avg_new',
       'self_reference_min_shares_new', 'self_reference_max_shares_new',
       'self_reference_avg_sharess_new', 'LDA_04_new',
       'global_subjectivity_new', 'global_sentiment_polarity_new',
       'rate_positive_words_new', 'avg_positive_polarity_new',
       'max_positive_polarity_new', 'avg_negative_polarity_new',
       'min_negative_polarity_new', 'max_negative_polarity_new',
       'title_subjectivity_new', 'title_sentiment_polarity_new',
       'abs_title_subjectivity_new', 'weekday_is_saturday',
       'weekday_is_sunday', 'is_weekend', 'data_channel_is_lifestyle',
       'data_channel_is_entertainment', 'data_channel_is_socmed',
       'data_channel_is_tech', 'data_channel_is_world']]

# %%
df8.shape

# %%
#  We found only 40 features

# %% [markdown]
# # RFE Features:35

# %%
cols = list(X.columns)
model = LogisticRegression()
#Initializing RFE model
rfe = RFE(model, 35)             
#Transforming data using RFE
X_rfe = rfe.fit_transform(X,y)  
#Fitting the data to model
model.fit(X_rfe,y)              
temp = pd.Series(rfe.support_,index = cols)
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)

# %%
df9=df3_con[['n_tokens_title', 'num_keywords', 'n_tokens_content_new',
       'num_hrefs_new', 'num_self_hrefs_new', 'num_imgs_new',
       'average_token_length_new', 'kw_min_min_new', 'kw_max_min_new',
       'kw_min_max_new', 'kw_max_max_new', 'kw_avg_max_new', 'kw_min_avg_new',
       'kw_max_avg_new', 'kw_avg_avg_new', 'self_reference_min_shares_new',
       'self_reference_max_shares_new', 'self_reference_avg_sharess_new',
       'global_subjectivity_new', 'global_sentiment_polarity_new',
       'rate_positive_words_new', 'avg_positive_polarity_new',
       'max_positive_polarity_new', 'avg_negative_polarity_new',
       'min_negative_polarity_new', 'max_negative_polarity_new',
       'title_sentiment_polarity_new', 'abs_title_subjectivity_new',
       'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend',
       'data_channel_is_entertainment', 'data_channel_is_socmed',
       'data_channel_is_tech', 'data_channel_is_world']]

# %%
df9.shape

# %%
X=df9

# %%
y=popular_label

# %%
modelscore_rf_35=[]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

logr_rf = LogisticRegression()

logr_rf.fit(X_train,y_train)
ypred=logr_rf.predict(X_test)

print("Tain score: " ,logr_rf.score(X_train, y_train)) #trainscore

lrrfe_2_score=metrics.accuracy_score(y_test, ypred)
print("Test Score: ", lrrfe_score) #testscore


lr_score1=metrics.classification_report(y_test,ypred)
print(lr_score1)

# %%
modelscore_rf_35.append(['logr_rf',lrrfe_2_score])

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_rf=KNeighborsClassifier()

knn_rf.fit(X_train,y_train)
ypred1=knn_rf.predict(X_test)

print("Tain score: " ,knn_rf.score(X_train, y_train)) #trainscore

knnrfe_2_score=metrics.accuracy_score(y_test, ypred1)
print("Test Score: ", knnrfe_2_score) #testscore


lr_score1=metrics.classification_report(y_test,ypred1)
print(lr_score1)

# %%
modelscore_rf_35.append(['knnrfe_2',knnrfe_2_score])

# %%
from sklearn.tree import DecisionTreeClassifier

dtc_rf=DecisionTreeClassifier()
dtc_rf.fit(X_train,y_train)

ypred2=dtc_rf.predict(X_test)

print("Tain score: " ,dtc_rf.score(X_train, y_train)) #trainscore

dtcrfe_2_score=metrics.accuracy_score(y_test, ypred2)
print("Test Score: ", dtcrfe_2_score) #testscore



lr_score1=metrics.classification_report(y_test,ypred2)
print(lr_score1)

# %%
modelscore_rf_35.append(['dtcrfe_2',dtcrfe_2_score])

# %%
from sklearn.naive_bayes import GaussianNB

gb_rf=GaussianNB()
gb_rf.fit(X_train,y_train)

ypred3=gb_rf.predict(X_test)

print("Tain score: " ,gb_rf.score(X_train, y_train)) #trainscore

gbrfe_2_score=metrics.accuracy_score(y_test, ypred3)
print("Test Score: ", gbrfe_2_score) #testscore

lr_score1=metrics.classification_report(y_test,ypred2)
print(lr_score1)

# %%
modelscore_rf_35.append(['gbrfe_2',gbrfe_2_score])

# %%
from sklearn.ensemble import RandomForestClassifier

rf_rfe=RandomForestClassifier()
rf_rfe.fit(X_train,y_train)

ypred4=rf_rfe.predict(X_test)

print("Tain score: " ,rf_rfe.score(X_train, y_train)) #trainscore

rf_rfe2_score=metrics.accuracy_score(y_test, ypred4)
print("Test Score: ", rf_rfe2_score) #testscore


cm_adboost=metrics.classification_report(y_test,ypred4)
print(cm_adboost)


lr_score1=metrics.classification_report(y_test,ypred2)
print(lr_score1)

# %%
modelscore_rf_35.append(['rf_rfe_2',rf_rfe2_score])

# %%
from sklearn.ensemble import AdaBoostClassifier
adboost=AdaBoostClassifier(base_estimator=rf_rfe,n_estimators=100,random_state=0)
adboost.fit(X_train,y_train)
pred_adboost=adboost.predict(X_test)

cm_adboost=metrics.classification_report(y_test,pred_adboost)
print(cm_adboost)

cm_adboost1=metrics.accuracy_score(y_test,pred_adboost)
print(cm_adboost1)

# %%
modelscore_rf_35.append(['adboost_35',cm_adboost1])

# %%
from xgboost import XGBClassifier
Xgb = XGBClassifier()
Xgb.fit(X_train,y_train)

ypred4=Xgb.predict(X_test)

print("Tain score: " ,Xgb.score(X_train, y_train)) #trainscore

Xgb_score=metrics.accuracy_score(y_test, ypred4)
print("Test Score: ", Xgb_score) #testscore

# %%
modelscore_rf_35.append(['XGboost_35',Xgb_score])

# %%
import lightgbm as lgb
from sklearn.metrics import roc_auc_score

train_data=lgb.Dataset(X_train,label=y_train)

#setting parameters for lightgbm
param = {'num_leaves':150, 'objective':'binary','max_depth':7,'learning_rate':.05,'max_bin':200}
param['metric'] = ['auc', 'binary_logloss']

#training our model using light gbm
num_round=50
lgbm=lgb.train(param,train_data,num_round)

#now predicting our model on test set 
ypred2=lgbm.predict(X_test)

auc_lgbm = roc_auc_score(y_test,ypred2)
auc_lgbm

# %%
modelscore_rf_35.append(['Light gbm',auc_lgbm])

# %%
scores = pd.DataFrame(modelscore_rf_35, columns =['Name', 'Score']) 
scores.sort_values(by=['Score'], inplace=True,ascending=False)
scores.set_index('Name', inplace=True)
scores

# %% [markdown]
# # With all Features of df3_con

# %%
X=df3_con

# %%
y=popular_label

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_rfe_55=RandomForestClassifier()
rf_rfe_55.fit(X_train,y_train)

ypred4=rf_rfe_55.predict(X_test)

print("Tain score: " ,rf_rfe_55.score(X_train, y_train)) #trainscore

rf_rfe_score=metrics.accuracy_score(y_test, ypred4)
print("Test Score: ", rf_rfe_score) #testscore

# %%
modelscore_rf_55=[]

# %%
modelscore_rf_55.append(['rf_rfe_55',rf_rfe_score])

# %%
from sklearn.ensemble import AdaBoostClassifier
adboost=AdaBoostClassifier(base_estimator=rf_rfe_55,n_estimators=120,random_state=0)
adboost.fit(X_train,y_train)
pred_adboost=adboost.predict(X_test)
cm_adboost=metrics.classification_report(y_test,pred_adboost)
print(cm_adboost)
cm_adboost1=metrics.accuracy_score(y_test,pred_adboost)
print("accuracy score: ",cm_adboost1)
Roc_score=roc_auc_score(y_test,pred_adboost)
print("roc_score: ",Roc_score)

# %%
modelscore_rf_55.append(['adboost_55',cm_adboost1])

# %%
from xgboost import XGBClassifier
Xgb = XGBClassifier()
Xgb.fit(X_train,y_train)

ypred4=Xgb.predict(X_test)

print("Tain score: " ,Xgb.score(X_train, y_train)) #trainscore

Xgb_score=metrics.accuracy_score(y_test, ypred4)
print("Test Score: ", Xgb_score) #testscore

# %%
modelscore_rf_55.append(['XGboost_55',Xgb_score])

# %%
import lightgbm as lgb
from sklearn.metrics import roc_auc_score

train_data=lgb.Dataset(X_train,label=y_train)

#setting parameters for lightgbm
param = {'num_leaves':150, 'objective':'binary','max_depth':7,'learning_rate':.05,'max_bin':200}
param['metric'] = ['auc', 'binary_logloss']

#training our model using light gbm
num_round=50
lgbm=lgb.train(param,train_data,num_round)

#now predicting our model on test set 
ypred2=lgbm.predict(X_test)

auc_lgbm = roc_auc_score(y_test,ypred2)
auc_lgbm

# %%
modelscore_rf_55.append(['light_gbm_55',auc_lgbm])

# %%
scores = pd.DataFrame(modelscore_rf_55, columns =['Name', 'Score']) 
scores.sort_values(by=['Score'], inplace=True,ascending=False)
scores.set_index('Name', inplace=True)
scores
